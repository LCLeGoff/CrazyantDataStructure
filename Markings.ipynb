# %% [markdown]
# # Results on markings

# %% [markdown]
# ## Spatial distribution

# %% [markdown]
# ### Positions

# %%
from AnalyseClasses.AnalyseMarkings import AnalyseMarkings

root = '/data/Dropbox/POSTDOC/CrazyAnt/Results_python/Data/'

for group in ['FMAB', 'FMABU', 'FMABW']:
	print(group)
	AnalyseMarkings(root, group).spatial_repartition_xy_markings()
# Out:
# FMAB
# FMABU
# FMABW

# %% [markdown]
# ### 2d-histograms

# %%
 
for group in ['FMAB', 'FMABU', 'FMABW']:
	print(group)
	AnalyseMarkings(root, group).spatial_repartition_xy_markings_2d_hist()
# Out:
# FMAB
# FMABU
# FMABW
